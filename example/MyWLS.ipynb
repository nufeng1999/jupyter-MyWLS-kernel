# %%
## ---------------------------
//%overwritefile
//%file:src/test1.wls
//%runprgargs:-print all -format PNG
//%outputtype:image/png
//%log:0
## ---------------------------
ListLinePlot[RandomFunction[WienerProcess[],{0,10,0.01},10]]
# Out:
# [MyWLSKernel215826] Info:file h:\Jupyter\ipynb\MyWLS\src/test1.wls created successfully
# [MyWLSKernel215826] Info:The process :h:\Jupyter\ipynb\MyWLS\src/test1.wls
# [MyWLSKernel215826] Info:cmd /c wolframscript -print all -format PNG -f h:\Jupyter\ipynb\MyWLS\src/test1.wls
# <div><img alt="Output" src="data:image/png;base64,..."></div>
# [MyWLSKernel215826] Info:The process end:12540

# %%
//%overwritefile
//%file:src/test2.wls
//%runprgargs:-print all -format html
//%outputtype:image/png
//%log:1
(*Print["--1----"]*)
(*Graphics3D[Sphere[ ]]*)
DynamicModule[{x}, {Slider[Dynamic[x]], Dynamic[x]}]

# %%
//%overwritefile
//%file:src/test3.wls
//%runprgargs:-print all
///%outputtype:image/png
//%log:0
(*Print["--1----"]*)


DynamicModule[{x}, {Slider[Dynamic[x]], Dynamic[x]}]
